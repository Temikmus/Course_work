# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats 
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df = pd.read_csv("resume.csv")

# %%
df = df.dropna(subset=['russian_salary'])

# %%
df.columns
# Out:
# Index(['id_resume', 'title', 'created_at', 'updated_at', 'age', 'gender',
#        'salary', 'currency', 'photo', 'total_experience', 'citizenship',
#        'area', 'level_education', 'university', 'count_additional_courses',
#        'employments', 'experience', 'language_eng', 'language_zho',
#        'schedules', 'skill_set', 'is_driver', 'professional_roles', 'url',
#        'russian_salary'],
#       dtype='object')

# %%
df = df.drop(columns=[
    'id_resume', 'created_at', 'updated_at', 'currency', 'salary', 
    'url'
])

# %%
df.head()
# Out:
#                   title   age  gender  photo  total_experience citizenship  \
# 10             Аналитик   NaN  female  False             243.0    {Россия}
# 20      Бизнес-аналитик   NaN    male  False               NaN    {Россия}
# 132            Аналитик  26.0    male   True              31.0    {Россия}
# 144  Системный аналитик  27.0    male  False              88.0    {Россия}
# 164            Аналитик  51.0    male  False             355.0    {Россия}
#
#                 area      level_education  \
# 10   Санкт-Петербург               Высшее
# 20      Натухаевская  Среднее специальное
# 132           Москва  Неоконченное высшее
# 144           Москва              Магистр
# 164           Москва               Высшее
#
#                                             university  \
# 10      {"Московский коммерческий университет",Москва}
# 20                                                  {}
# 132  {"Московский государственный университет имени...
# 144  {"Российская академия народного хозяйства и го...
# 164  {"Серпуховской военный институт (филиал) Военн...
#
#      count_additional_courses  \
# 10                        NaN
# 20                        NaN
# 132                       NaN
# 144                       NaN
# 164                       NaN
#
#                                            employments  \
# 10                                {"Полная занятость"}
# 20                                {"Полная занятость"}
# 132  {"Полная занятость","Частичная занятость","Про...
# 144                               {"Полная занятость"}
# 164                               {"Полная занятость"}
#
#                                       experience language_eng language_zho  \
# 10                           {Минимакс,Минимакс}          NaN          NaN
# 20                                            {}          NaN          NaN
# 132                              {Техноласточка}           c1          NaN
# 144  {Ингосстрах,"ООО «дистанционная медицина»"}          NaN          NaN
# 164               {"Вооруженные силы РФ (РВСН)"}           a1          NaN
#
#                                              schedules  \
# 10                                     {"Полный день"}
# 20                  {"Полный день","Удаленная работа"}
# 132  {"Полный день","Сменный график","Гибкий график...
# 144                                    {"Полный день"}
# 164                                    {"Полный день"}
#
#                                              skill_set  is_driver  \
# 10                                {"Аналитика данных"}       True
# 20   {Ответственность,"MS PowerPoint","Подготовка п...      False
# 132  {"Аналитическое мышление",Python,"Английский я...      False
# 144  {"Ruby On Rails",Ruby,Json,UML,Redis,Kafka,Nod...      False
# 164                    {Работоспособность,Обучаемость}      False
#
#                   professional_roles  russian_salary
# 10                        {Аналитик}        100000.0
# 20                 {Бизнес-аналитик}         80000.0
# 132                       {Аналитик}        160000.0
# 144  {Аналитик,"Системный аналитик"}        250000.0
# 164                       {Аналитик}         80000.0

# %%
language_levels = {'a1': 1, 'a2': 2, 'b1': 3, 'b2': 4, 'c1': 5, 'c2': 6, 'l1': 7}
df['language_eng_encoded'] = df['language_eng'].map(language_levels)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4024 entries, 10 to 9117
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     4024 non-null   object
#  1   age                       3760 non-null   float64
#  2   gender                    4024 non-null   object
#  3   photo                     4024 non-null   bool
#  4   total_experience          3896 non-null   float64
#  5   citizenship               4024 non-null   object
#  6   area                      4024 non-null   object
#  7   level_education           4024 non-null   object
#  8   university                4024 non-null   object
#  9   count_additional_courses  1748 non-null   float64
#  10  employments               4024 non-null   object
#  11  experience                4024 non-null   object
#  12  language_eng              3062 non-null   object
#  13  language_zho              28 non-null     object
#  14  schedules                 4024 non-null   object
#  15  skill_set                 4024 non-null   object
#  16  is_driver                 4024 non-null   bool
#  17  professional_roles        4024 non-null   object
#  18  russian_salary            4024 non-null   float64
#  19  language_eng_encoded      3062 non-null   float64
# dtypes: bool(2), float64(5), object(13)
# memory usage: 605.2+ KB

# %%
df = df.drop(columns=[
    'language_zho', 'language_eng'
])
df = df.dropna(subset=['age', 'total_experience', 'language_eng_encoded'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2842 entries, 132 to 9117
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     2842 non-null   object
#  1   age                       2842 non-null   float64
#  2   gender                    2842 non-null   object
#  3   photo                     2842 non-null   bool
#  4   total_experience          2842 non-null   float64
#  5   citizenship               2842 non-null   object
#  6   area                      2842 non-null   object
#  7   level_education           2842 non-null   object
#  8   university                2842 non-null   object
#  9   count_additional_courses  1337 non-null   float64
#  10  employments               2842 non-null   object
#  11  experience                2842 non-null   object
#  12  schedules                 2842 non-null   object
#  13  skill_set                 2842 non-null   object
#  14  is_driver                 2842 non-null   bool
#  15  professional_roles        2842 non-null   object
#  16  russian_salary            2842 non-null   float64
#  17  language_eng_encoded      2842 non-null   float64
# dtypes: bool(2), float64(5), object(11)
# memory usage: 383.0+ KB

# %%
df["has_photo"] = df["photo"].astype(int)
df["has_driver_license"] = df["is_driver"].astype(int)

# %%
df = df.drop(columns=[
    'title'
])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2842 entries, 132 to 9117
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       2842 non-null   float64
#  1   gender                    2842 non-null   object
#  2   photo                     2842 non-null   bool
#  3   total_experience          2842 non-null   float64
#  4   citizenship               2842 non-null   object
#  5   area                      2842 non-null   object
#  6   level_education           2842 non-null   object
#  7   university                2842 non-null   object
#  8   count_additional_courses  1337 non-null   float64
#  9   employments               2842 non-null   object
#  10  experience                2842 non-null   object
#  11  schedules                 2842 non-null   object
#  12  skill_set                 2842 non-null   object
#  13  is_driver                 2842 non-null   bool
#  14  professional_roles        2842 non-null   object
#  15  russian_salary            2842 non-null   float64
#  16  language_eng_encoded      2842 non-null   float64
#  17  has_photo                 2842 non-null   int32
#  18  has_driver_license        2842 non-null   int32
# dtypes: bool(2), float64(5), int32(2), object(10)
# memory usage: 383.0+ KB

# %%
df = df.drop(columns=[
    'is_driver', 'photo'
])
df = df.rename(columns={
    "has_driver_license": "is_driver",
    "has_photo": "photo", 
    'language_eng_encoded': 'language_eng'
})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2842 entries, 132 to 9117
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       2842 non-null   float64
#  1   gender                    2842 non-null   object
#  2   total_experience          2842 non-null   float64
#  3   citizenship               2842 non-null   object
#  4   area                      2842 non-null   object
#  5   level_education           2842 non-null   object
#  6   university                2842 non-null   object
#  7   count_additional_courses  1337 non-null   float64
#  8   employments               2842 non-null   object
#  9   experience                2842 non-null   object
#  10  schedules                 2842 non-null   object
#  11  skill_set                 2842 non-null   object
#  12  professional_roles        2842 non-null   object
#  13  russian_salary            2842 non-null   float64
#  14  language_eng              2842 non-null   float64
#  15  photo                     2842 non-null   int32
#  16  is_driver                 2842 non-null   int32
# dtypes: float64(5), int32(2), object(10)
# memory usage: 377.5+ KB

# %%
df = pd.get_dummies(df, columns=['gender'], dtype=int)
df.head()
# Out:
#       age  total_experience citizenship         area      level_education  \
# 132  26.0              31.0    {Россия}       Москва  Неоконченное высшее
# 164  51.0             355.0    {Россия}       Москва               Высшее
# 219  40.0             224.0    {Россия}      Иркутск               Высшее
# 273  31.0              33.0    {Россия}       Москва               Высшее
# 284  22.0              31.0    {Россия}  Владивосток  Неоконченное высшее
#
#                                             university  \
# 132  {"Московский государственный университет имени...
# 164  {"Серпуховской военный институт (филиал) Военн...
# 219  {"ГАПОУ Иркутской области «Центр обучения и со...
# 273  {"Московский государственный технический униве...
# 284  {"Дальневосточный федеральный университет",Вла...
#
#      count_additional_courses  \
# 132                       NaN
# 164                       NaN
# 219                       NaN
# 273                       NaN
# 284                       2.0
#
#                                            employments  \
# 132  {"Полная занятость","Частичная занятость","Про...
# 164                               {"Полная занятость"}
# 219                               {"Полная занятость"}
# 273         {"Полная занятость","Частичная занятость"}
# 284                               {"Полная занятость"}
#
#                                             experience  \
# 132                                    {Техноласточка}
# 164                     {"Вооруженные силы РФ (РВСН)"}
# 219              {"Газпромбанк (АО)","Банк ВТБ (ПАО)"}
# 273  {"CORE (проект СбераБанка)","Сбербанк - Технол...
# 284  {"Сеть магазинов цифровой и бытовой техники DN...
#
#                                              schedules  \
# 132  {"Полный день","Сменный график","Гибкий график...
# 164                                    {"Полный день"}
# 219                                    {"Полный день"}
# 273                 {"Полный день","Удаленная работа"}
# 284                               {"Удаленная работа"}
#
#                                              skill_set  \
# 132  {"Аналитическое мышление",Python,"Английский я...
# 164                    {Работоспособность,Обучаемость}
# 219                                                 {}
# 273  {"Microsoft Office","Постановка задач разработ...
# 284  {Docker,Python,SQL,"Английский язык","Математи...
#
#                            professional_roles  russian_salary  language_eng  \
# 132                                {Аналитик}        160000.0           5.0
# 164                                {Аналитик}         80000.0           1.0
# 219  {Аналитик,Маркетолог-аналитик,Экономист}         70000.0           1.0
# 273    {Бизнес-аналитик,"Системный аналитик"}        180000.0           2.0
# 284                          {Дата-сайентист}        200000.0           4.0
#
#      photo  is_driver  gender_female  gender_male
# 132      1          0              0            1
# 164      0          0              0            1
# 219      0          1              1            0
# 273      1          1              0            1
# 284      0          0              0            1

# %%
import re
from collections import Counter

def clean_city(city_str):
    city_str = city_str.strip('{}')
    city = re.findall(r'(?:[^,"]|"(?:\\.|[^"])*")+', city_str)
    city = [s.strip().strip('"') for s in city if s.strip()]
    return city

df['citizenship_cleaned'] = df['citizenship'].apply(clean_city)
df.head()
# Out:
#       age  total_experience citizenship         area      level_education  \
# 132  26.0              31.0    {Россия}       Москва  Неоконченное высшее
# 164  51.0             355.0    {Россия}       Москва               Высшее
# 219  40.0             224.0    {Россия}      Иркутск               Высшее
# 273  31.0              33.0    {Россия}       Москва               Высшее
# 284  22.0              31.0    {Россия}  Владивосток  Неоконченное высшее
#
#                                             university  \
# 132  {"Московский государственный университет имени...
# 164  {"Серпуховской военный институт (филиал) Военн...
# 219  {"ГАПОУ Иркутской области «Центр обучения и со...
# 273  {"Московский государственный технический униве...
# 284  {"Дальневосточный федеральный университет",Вла...
#
#      count_additional_courses  \
# 132                       NaN
# 164                       NaN
# 219                       NaN
# 273                       NaN
# 284                       2.0
#
#                                            employments  \
# 132  {"Полная занятость","Частичная занятость","Про...
# 164                               {"Полная занятость"}
# 219                               {"Полная занятость"}
# 273         {"Полная занятость","Частичная занятость"}
# 284                               {"Полная занятость"}
#
#                                             experience  \
# 132                                    {Техноласточка}
# 164                     {"Вооруженные силы РФ (РВСН)"}
# 219              {"Газпромбанк (АО)","Банк ВТБ (ПАО)"}
# 273  {"CORE (проект СбераБанка)","Сбербанк - Технол...
# 284  {"Сеть магазинов цифровой и бытовой техники DN...
#
#                                              schedules  \
# 132  {"Полный день","Сменный график","Гибкий график...
# 164                                    {"Полный день"}
# 219                                    {"Полный день"}
# 273                 {"Полный день","Удаленная работа"}
# 284                               {"Удаленная работа"}
#
#                                              skill_set  \
# 132  {"Аналитическое мышление",Python,"Английский я...
# 164                    {Работоспособность,Обучаемость}
# 219                                                 {}
# 273  {"Microsoft Office","Постановка задач разработ...
# 284  {Docker,Python,SQL,"Английский язык","Математи...
#
#                            professional_roles  russian_salary  language_eng  \
# 132                                {Аналитик}        160000.0           5.0
# 164                                {Аналитик}         80000.0           1.0
# 219  {Аналитик,Маркетолог-аналитик,Экономист}         70000.0           1.0
# 273    {Бизнес-аналитик,"Системный аналитик"}        180000.0           2.0
# 284                          {Дата-сайентист}        200000.0           4.0
#
#      photo  is_driver  gender_female  gender_male citizenship_cleaned
# 132      1          0              0            1            [Россия]
# 164      0          0              0            1            [Россия]
# 219      0          1              1            0            [Россия]
# 273      1          1              0            1            [Россия]
# 284      0          0              0            1            [Россия]

# %%
df['citizenship_cleaned'].value_counts()
# Out:
# citizenship_cleaned
# [Россия]                 2742
# [Russia]                   34
# [Казахстан]                15
# [Беларусь]                 10
# [Армения]                   7
# [Казахстан, Россия]         4
# [Другое, Россия]            4
# [Украина]                   2
# [Таджикистан]               2
# [Израиль, Россия]           2
# [Молдова, Россия]           2
# [Кыргызстан]                2
# [Узбекистан]                2
# [Мексика]                   1
# [Монголия]                  1
# [Россия, Тунис]             1
# [Нигерия]                   1
# [Германия, Россия]          1
# [Армения, Россия]           1
# [Литва]                     1
# [Россия, США]               1
# [Кыргызстан, Россия]        1
# [Молдова]                   1
# [Беларусь, Россия]          1
# [Россия, Таджикистан]       1
# [Tajikistan]                1
# [Другое]                    1
# Name: count, dtype: int64

# %%
# Функция для проверки наличия России/Russia в списке
def is_russia(citizenships):
    if isinstance(citizenships, list):  # Если это список
        return any(
            isinstance(c, str) and 
            ('россия' in c.lower() or 'russia' in c.lower()) 
            for c in citizenships
        )
    return False  # Если не список (на случай NaN или других типов)

# Создаем столбцы
df['citizenship_russia'] = df['citizenship_cleaned'].apply(is_russia).astype(int)
df['citizenship_other'] = (~df['citizenship_cleaned'].apply(is_russia)).astype(int)

# %%
df = df.drop(columns=[
    'citizenship_cleaned', 'citizenship'
])
df['citizenship_russia'].value_counts()
# Out:
# citizenship_russia
# 1    2795
# 0      47
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'total_experience', 'area', 'level_education', 'university',
#        'count_additional_courses', 'employments', 'experience', 'schedules',
#        'skill_set', 'professional_roles', 'russian_salary', 'language_eng',
#        'photo', 'is_driver', 'gender_female', 'gender_male',
#        'citizenship_russia', 'citizenship_other'],
#       dtype='object')

# %%
df.head()
# Out:
#       age  total_experience         area      level_education  \
# 132  26.0              31.0       Москва  Неоконченное высшее
# 164  51.0             355.0       Москва               Высшее
# 219  40.0             224.0      Иркутск               Высшее
# 273  31.0              33.0       Москва               Высшее
# 284  22.0              31.0  Владивосток  Неоконченное высшее
#
#                                             university  \
# 132  {"Московский государственный университет имени...
# 164  {"Серпуховской военный институт (филиал) Военн...
# 219  {"ГАПОУ Иркутской области «Центр обучения и со...
# 273  {"Московский государственный технический униве...
# 284  {"Дальневосточный федеральный университет",Вла...
#
#      count_additional_courses  \
# 132                       NaN
# 164                       NaN
# 219                       NaN
# 273                       NaN
# 284                       2.0
#
#                                            employments  \
# 132  {"Полная занятость","Частичная занятость","Про...
# 164                               {"Полная занятость"}
# 219                               {"Полная занятость"}
# 273         {"Полная занятость","Частичная занятость"}
# 284                               {"Полная занятость"}
#
#                                             experience  \
# 132                                    {Техноласточка}
# 164                     {"Вооруженные силы РФ (РВСН)"}
# 219              {"Газпромбанк (АО)","Банк ВТБ (ПАО)"}
# 273  {"CORE (проект СбераБанка)","Сбербанк - Технол...
# 284  {"Сеть магазинов цифровой и бытовой техники DN...
#
#                                              schedules  \
# 132  {"Полный день","Сменный график","Гибкий график...
# 164                                    {"Полный день"}
# 219                                    {"Полный день"}
# 273                 {"Полный день","Удаленная работа"}
# 284                               {"Удаленная работа"}
#
#                                              skill_set  \
# 132  {"Аналитическое мышление",Python,"Английский я...
# 164                    {Работоспособность,Обучаемость}
# 219                                                 {}
# 273  {"Microsoft Office","Постановка задач разработ...
# 284  {Docker,Python,SQL,"Английский язык","Математи...
#
#                            professional_roles  russian_salary  language_eng  \
# 132                                {Аналитик}        160000.0           5.0
# 164                                {Аналитик}         80000.0           1.0
# 219  {Аналитик,Маркетолог-аналитик,Экономист}         70000.0           1.0
# 273    {Бизнес-аналитик,"Системный аналитик"}        180000.0           2.0
# 284                          {Дата-сайентист}        200000.0           4.0
#
#      photo  is_driver  gender_female  gender_male  citizenship_russia  \
# 132      1          0              0            1                   1
# 164      0          0              0            1                   1
# 219      0          1              1            0                   1
# 273      1          1              0            1                   1
# 284      0          0              0            1                   1
#
#      citizenship_other
# 132                  0
# 164                  0
# 219                  0
# 273                  0
# 284                  0

# %%
top_area = df['area'].value_counts().head(5).index
df['area_group'] = df['area'].apply(lambda x: x if x in top_area else 'other')
df = pd.get_dummies(df, columns=['area_group'], prefix='area', dtype=int)
df = df.drop(columns=['area'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2842 entries, 132 to 9117
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       2842 non-null   float64
#  1   total_experience          2842 non-null   float64
#  2   level_education           2842 non-null   object
#  3   university                2842 non-null   object
#  4   count_additional_courses  1337 non-null   float64
#  5   employments               2842 non-null   object
#  6   experience                2842 non-null   object
#  7   schedules                 2842 non-null   object
#  8   skill_set                 2842 non-null   object
#  9   professional_roles        2842 non-null   object
#  10  russian_salary            2842 non-null   float64
#  11  language_eng              2842 non-null   float64
#  12  photo                     2842 non-null   int32
#  13  is_driver                 2842 non-null   int32
#  14  gender_female             2842 non-null   int32
#  15  gender_male               2842 non-null   int32
#  16  citizenship_russia        2842 non-null   int32
#  17  citizenship_other         2842 non-null   int32
#  18  area_other                2842 non-null   int32
#  19  area_Казань               2842 non-null   int32
#  20  area_Краснодар            2842 non-null   int32
#  21  area_Москва               2842 non-null   int32
#  22  area_Нижний Новгород      2842 non-null   int32
#  23  area_Санкт-Петербург      2842 non-null   int32
# dtypes: float64(5), int32(12), object(7)
# memory usage: 421.9+ KB

# %%
df = df.drop(columns=[
    'professional_roles'
])

# %%
def clean_skills(skill_str):
    skill_str = skill_str.strip('{}')
    skills = re.findall(r'(?:[^,"]|"(?:\\.|[^"])*")+', skill_str)
    skills = [s.strip().strip('"') for s in skills if s.strip()]
    return skills

df['skills_cleaned'] = df['skill_set'].apply(clean_skills)

selected_skills = [
    'MS Excel',
    'Работа с большим объемом информации',
    'Аналитическое мышление',
    'SQL',
    'MS PowerPoint',
    'Python',
    'BPMN',
    'Бизнес-анализ',
    'Разработка технических заданий',
    'Atlassian Jira',
    'Постановка задач разработчикам',
    'Системный анализ',
    'UML',
    'Power BI',
    'Atlassian Confluence',
    'Моделирование бизнес процессов',
    'Финансовый анализ',
    'MS SQL',
    'PostgreSQL',
    'Power Query',
    'MS Visio',
    'Статистический анализ',
    'Экономический анализ',
    'Управленческая отчетность',
    'Автоматизация процессов',
    'Визуализация данных',
    'Git',
    'Оптимизация бизнес-процессов',
    'Прогнозирование',
    'Анализ бизнес показателей',
    'Анализ финансовых показателей',
    '1С: Предприятие 8'
]


for skill in selected_skills:
    df[f'skill_{skill}'] = df['skills_cleaned'].apply(lambda x: 1 if skill in x else 0)

df = df.drop(columns=['skill_set', 'skills_cleaned'])

# %%
df.columns
# Out:
# Index(['age', 'total_experience', 'level_education', 'university',
#        'count_additional_courses', 'employments', 'experience', 'schedules',
#        'russian_salary', 'language_eng', 'photo', 'is_driver', 'gender_female',
#        'gender_male', 'citizenship_russia', 'citizenship_other', 'area_other',
#        'area_Казань', 'area_Краснодар', 'area_Москва', 'area_Нижний Новгород',
#        'area_Санкт-Петербург', 'skill_MS Excel',
#        'skill_Работа с большим объемом информации',
#        'skill_Аналитическое мышление', 'skill_SQL', 'skill_MS PowerPoint',
#        'skill_Python', 'skill_BPMN', 'skill_Бизнес-анализ',
#        'skill_Разработка технических заданий', 'skill_Atlassian Jira',
#        'skill_Постановка задач разработчикам', 'skill_Системный анализ',
#        'skill_UML', 'skill_Power BI', 'skill_Atlassian Confluence',
#        'skill_Моделирование бизнес процессов', 'skill_Финансовый анализ',
#        'skill_MS SQL', 'skill_PostgreSQL', 'skill_Power Query',
#        'skill_MS Visio', 'skill_Статистический анализ',
#        'skill_Экономический анализ', 'skill_Управленческая отчетность',
#        'skill_Автоматизация процессов', 'skill_Визуализация данных',
#        'skill_Git', 'skill_Оптимизация бизнес-процессов',
#        'skill_Прогнозирование', 'skill_Анализ бизнес показателей',
#        'skill_Анализ финансовых показателей', 'skill_1С: Предприятие 8'],
#       dtype='object')

# %%
def clean_skills(skill_str):
    skill_str = skill_str.strip('{}')
    skills = re.findall(r'(?:[^,"]|"(?:\\.|[^"])*")+', skill_str)
    skills = [s.strip().strip('"') for s in skills if s.strip()]
    return skills

df['schedules_cleaned'] = df['schedules'].apply(clean_skills)

selected_schedules = [
    'Полный день',
    'Удаленная работа',
    'Гибкий график',
    'Сменный график',
    'Вахтовый метод'
]


for schedule in selected_schedules:
    df[f'schedules_{schedule}'] = df['schedules_cleaned'].apply(lambda x: 1 if schedule in x else 0)

df = df.drop(columns=['schedules', 'schedules_cleaned'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2842 entries, 132 to 9117
# Data columns (total 58 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   age                                        2842 non-null   float64
#  1   total_experience                           2842 non-null   float64
#  2   level_education                            2842 non-null   object
#  3   university                                 2842 non-null   object
#  4   count_additional_courses                   1337 non-null   float64
#  5   employments                                2842 non-null   object
#  6   experience                                 2842 non-null   object
#  7   russian_salary                             2842 non-null   float64
#  8   language_eng                               2842 non-null   float64
#  9   photo                                      2842 non-null   int32
#  10  is_driver                                  2842 non-null   int32
#  11  gender_female                              2842 non-null   int32
#  12  gender_male                                2842 non-null   int32
#  13  citizenship_russia                         2842 non-null   int32
#  14  citizenship_other                          2842 non-null   int32
#  15  area_other                                 2842 non-null   int32
#  16  area_Казань                                2842 non-null   int32
#  17  area_Краснодар                             2842 non-null   int32
#  18  area_Москва                                2842 non-null   int32
#  19  area_Нижний Новгород                       2842 non-null   int32
#  20  area_Санкт-Петербург                       2842 non-null   int32
#  21  skill_MS Excel                             2842 non-null   int64
#  22  skill_Работа с большим объемом информации  2842 non-null   int64
#  23  skill_Аналитическое мышление               2842 non-null   int64
#  24  skill_SQL                                  2842 non-null   int64
#  25  skill_MS PowerPoint                        2842 non-null   int64
#  26  skill_Python                               2842 non-null   int64
#  27  skill_BPMN                                 2842 non-null   int64
#  28  skill_Бизнес-анализ                        2842 non-null   int64
#  29  skill_Разработка технических заданий       2842 non-null   int64
#  30  skill_Atlassian Jira                       2842 non-null   int64
#  31  skill_Постановка задач разработчикам       2842 non-null   int64
#  32  skill_Системный анализ                     2842 non-null   int64
#  33  skill_UML                                  2842 non-null   int64
#  34  skill_Power BI                             2842 non-null   int64
#  35  skill_Atlassian Confluence                 2842 non-null   int64
#  36  skill_Моделирование бизнес процессов       2842 non-null   int64
#  37  skill_Финансовый анализ                    2842 non-null   int64
#  38  skill_MS SQL                               2842 non-null   int64
#  39  skill_PostgreSQL                           2842 non-null   int64
#  40  skill_Power Query                          2842 non-null   int64
#  41  skill_MS Visio                             2842 non-null   int64
#  42  skill_Статистический анализ                2842 non-null   int64
#  43  skill_Экономический анализ                 2842 non-null   int64
#  44  skill_Управленческая отчетность            2842 non-null   int64
#  45  skill_Автоматизация процессов              2842 non-null   int64
#  46  skill_Визуализация данных                  2842 non-null   int64
#  47  skill_Git                                  2842 non-null   int64
#  48  skill_Оптимизация бизнес-процессов         2842 non-null   int64
#  49  skill_Прогнозирование                      2842 non-null   int64
#  50  skill_Анализ бизнес показателей            2842 non-null   int64
#  51  skill_Анализ финансовых показателей        2842 non-null   int64
#  52  skill_1С: Предприятие 8                    2842 non-null   int64
#  53  schedules_Полный день                      2842 non-null   int64
#  54  schedules_Удаленная работа                 2842 non-null   int64
#  55  schedules_Гибкий график                    2842 non-null   int64
#  56  schedules_Сменный график                   2842 non-null   int64
#  57  schedules_Вахтовый метод                   2842 non-null   int64
# dtypes: float64(5), int32(12), int64(37), object(4)
# memory usage: 1.1+ MB

# %%
# Создаем mapping-словарь для преобразования
education_levels = {
    'Среднее': 1,
    'Среднее специальное': 2,
    'Неоконченное высшее': 3,
    'Incomplete higher': 3,
    'Бакалавр': 4,
    'Высшее': 4,
    'Bachelor': 4,
    'Higher': 4,  # Предполагаем, что это эквивалент бакалавра
    'Магистр': 5,
    'Master': 5,
    'Кандидат наук': 6,
    'PhD': 6,
    'Доктор наук': 7
}

# Применяем преобразование
df['education_level'] = df['level_education'].map(education_levels)

# Проверяем распределение
print(df['education_level'].value_counts().sort_index())
# Out:
# education_level
# 1      12
# 2      88
# 3     162
# 4    2105
# 5     429
# 6      42
# 7       4
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2842 entries, 132 to 9117
# Data columns (total 59 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   age                                        2842 non-null   float64
#  1   total_experience                           2842 non-null   float64
#  2   level_education                            2842 non-null   object
#  3   university                                 2842 non-null   object
#  4   count_additional_courses                   1337 non-null   float64
#  5   employments                                2842 non-null   object
#  6   experience                                 2842 non-null   object
#  7   russian_salary                             2842 non-null   float64
#  8   language_eng                               2842 non-null   float64
#  9   photo                                      2842 non-null   int32
#  10  is_driver                                  2842 non-null   int32
#  11  gender_female                              2842 non-null   int32
#  12  gender_male                                2842 non-null   int32
#  13  citizenship_russia                         2842 non-null   int32
#  14  citizenship_other                          2842 non-null   int32
#  15  area_other                                 2842 non-null   int32
#  16  area_Казань                                2842 non-null   int32
#  17  area_Краснодар                             2842 non-null   int32
#  18  area_Москва                                2842 non-null   int32
#  19  area_Нижний Новгород                       2842 non-null   int32
#  20  area_Санкт-Петербург                       2842 non-null   int32
#  21  skill_MS Excel                             2842 non-null   int64
#  22  skill_Работа с большим объемом информации  2842 non-null   int64
#  23  skill_Аналитическое мышление               2842 non-null   int64
#  24  skill_SQL                                  2842 non-null   int64
#  25  skill_MS PowerPoint                        2842 non-null   int64
#  26  skill_Python                               2842 non-null   int64
#  27  skill_BPMN                                 2842 non-null   int64
#  28  skill_Бизнес-анализ                        2842 non-null   int64
#  29  skill_Разработка технических заданий       2842 non-null   int64
#  30  skill_Atlassian Jira                       2842 non-null   int64
#  31  skill_Постановка задач разработчикам       2842 non-null   int64
#  32  skill_Системный анализ                     2842 non-null   int64
#  33  skill_UML                                  2842 non-null   int64
#  34  skill_Power BI                             2842 non-null   int64
#  35  skill_Atlassian Confluence                 2842 non-null   int64
#  36  skill_Моделирование бизнес процессов       2842 non-null   int64
#  37  skill_Финансовый анализ                    2842 non-null   int64
#  38  skill_MS SQL                               2842 non-null   int64
#  39  skill_PostgreSQL                           2842 non-null   int64
#  40  skill_Power Query                          2842 non-null   int64
#  41  skill_MS Visio                             2842 non-null   int64
#  42  skill_Статистический анализ                2842 non-null   int64
#  43  skill_Экономический анализ                 2842 non-null   int64
#  44  skill_Управленческая отчетность            2842 non-null   int64
#  45  skill_Автоматизация процессов              2842 non-null   int64
#  46  skill_Визуализация данных                  2842 non-null   int64
#  47  skill_Git                                  2842 non-null   int64
#  48  skill_Оптимизация бизнес-процессов         2842 non-null   int64
#  49  skill_Прогнозирование                      2842 non-null   int64
#  50  skill_Анализ бизнес показателей            2842 non-null   int64
#  51  skill_Анализ финансовых показателей        2842 non-null   int64
#  52  skill_1С: Предприятие 8                    2842 non-null   int64
#  53  schedules_Полный день                      2842 non-null   int64
#  54  schedules_Удаленная работа                 2842 non-null   int64
#  55  schedules_Гибкий график                    2842 non-null   int64
#  56  schedules_Сменный график                   2842 non-null   int64
#  57  schedules_Вахтовый метод                   2842 non-null   int64
#  58  education_level                            2842 non-null   int64
# dtypes: float64(5), int32(12), int64(38), object(4)
# memory usage: 1.2+ MB

# %%
df = df.drop(columns=[
    'level_education'
])
df = df.rename(columns={
    "education_level": "level_education"
})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2842 entries, 132 to 9117
# Data columns (total 58 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   age                                        2842 non-null   float64
#  1   total_experience                           2842 non-null   float64
#  2   university                                 2842 non-null   object
#  3   count_additional_courses                   1337 non-null   float64
#  4   employments                                2842 non-null   object
#  5   experience                                 2842 non-null   object
#  6   russian_salary                             2842 non-null   float64
#  7   language_eng                               2842 non-null   float64
#  8   photo                                      2842 non-null   int32
#  9   is_driver                                  2842 non-null   int32
#  10  gender_female                              2842 non-null   int32
#  11  gender_male                                2842 non-null   int32
#  12  citizenship_russia                         2842 non-null   int32
#  13  citizenship_other                          2842 non-null   int32
#  14  area_other                                 2842 non-null   int32
#  15  area_Казань                                2842 non-null   int32
#  16  area_Краснодар                             2842 non-null   int32
#  17  area_Москва                                2842 non-null   int32
#  18  area_Нижний Новгород                       2842 non-null   int32
#  19  area_Санкт-Петербург                       2842 non-null   int32
#  20  skill_MS Excel                             2842 non-null   int64
#  21  skill_Работа с большим объемом информации  2842 non-null   int64
#  22  skill_Аналитическое мышление               2842 non-null   int64
#  23  skill_SQL                                  2842 non-null   int64
#  24  skill_MS PowerPoint                        2842 non-null   int64
#  25  skill_Python                               2842 non-null   int64
#  26  skill_BPMN                                 2842 non-null   int64
#  27  skill_Бизнес-анализ                        2842 non-null   int64
#  28  skill_Разработка технических заданий       2842 non-null   int64
#  29  skill_Atlassian Jira                       2842 non-null   int64
#  30  skill_Постановка задач разработчикам       2842 non-null   int64
#  31  skill_Системный анализ                     2842 non-null   int64
#  32  skill_UML                                  2842 non-null   int64
#  33  skill_Power BI                             2842 non-null   int64
#  34  skill_Atlassian Confluence                 2842 non-null   int64
#  35  skill_Моделирование бизнес процессов       2842 non-null   int64
#  36  skill_Финансовый анализ                    2842 non-null   int64
#  37  skill_MS SQL                               2842 non-null   int64
#  38  skill_PostgreSQL                           2842 non-null   int64
#  39  skill_Power Query                          2842 non-null   int64
#  40  skill_MS Visio                             2842 non-null   int64
#  41  skill_Статистический анализ                2842 non-null   int64
#  42  skill_Экономический анализ                 2842 non-null   int64
#  43  skill_Управленческая отчетность            2842 non-null   int64
#  44  skill_Автоматизация процессов              2842 non-null   int64
#  45  skill_Визуализация данных                  2842 non-null   int64
#  46  skill_Git                                  2842 non-null   int64
#  47  skill_Оптимизация бизнес-процессов         2842 non-null   int64
#  48  skill_Прогнозирование                      2842 non-null   int64
#  49  skill_Анализ бизнес показателей            2842 non-null   int64
#  50  skill_Анализ финансовых показателей        2842 non-null   int64
#  51  skill_1С: Предприятие 8                    2842 non-null   int64
#  52  schedules_Полный день                      2842 non-null   int64
#  53  schedules_Удаленная работа                 2842 non-null   int64
#  54  schedules_Гибкий график                    2842 non-null   int64
#  55  schedules_Сменный график                   2842 non-null   int64
#  56  schedules_Вахтовый метод                   2842 non-null   int64
#  57  level_education                            2842 non-null   int64
# dtypes: float64(5), int32(12), int64(38), object(3)
# memory usage: 1.1+ MB

# %%
def clean_skills(skill_str):
    skill_str = skill_str.strip('{}')
    skills = re.findall(r'(?:[^,"]|"(?:\\.|[^"])*")+', skill_str)
    skills = [s.strip().strip('"') for s in skills if s.strip()]
    return skills

df['experience_cleaned'] = df['experience'].apply(clean_skills)

selected_experience = [
    'Сбер',
    'Индивидуальное предпринимательство / частная практика / фриланс',
    'Розничная сеть',
    'Магнит',
    'Банк ВТБ',
    'Т-Банк',
    'Группа компаний',
    'Яндекс',
    'Ростелеком',
    'МТС',
    'Альфа-Банк',
    'Росбанк',
    'Россельхозбанк',
    'Ozon',
    'Билайн',
    'Интернет-магазин',
    'Тинькофф Банк',
    'Пепсико Россия',
    'РЖД',
    'НИУ ВШЭ',
    'Промсвязьбанк',
    'EY Russia',
    'Газпромбанк',
    'Raiffeisenbank',
    'X5 Retail Group',
    'Совкомбанк',
    'ФК Открытие',
    'ЦБ РФ',
    'МегаФон',
    'Банк Уралсиб',
    'Яндекс Практикум',
    'Почта России',
    'Philip Morris International',
    'VK',
    'Иннотех',
    'Банк Хоум Кредит',
    'Wildberries',
    'Аэропорт Домодедово',
    'Tele2',
    'Лента'
]


for experience in selected_experience:
    df[f'experience_{experience}'] = df['experience_cleaned'].apply(lambda x: 1 if experience in x else 0)

df = df.drop(columns=['experience', 'experience_cleaned'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2842 entries, 132 to 9117
# Data columns (total 97 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0
#  58  experience_Индивидуальное предпринимательство / частная практика / фриланс  2842 non-null   int64
#  59  experience_Розничная сеть                                                   2842 non-null   int64
#  60  experience_Магнит                                                           2842 non-null   int64
#  61  experience_Банк ВТБ                                                         2842 non-null   int64
#  62  experience_Т-Банк                                                           2842 non-null   int64
#  63  experience_Группа компаний                                                  2842 non-null   int64
#  64  experience_Яндекс                                                           2842 non-null   int64
#  65  experience_Ростелеком                                                       2842 non-null   int64
#  66  experience_МТС                                                              2842 non-null   int64
#  67  experience_Альфа-Банк                                                       2842 non-null   int64
#  68  experience_Росбанк                                                          2842 non-null   int64
#  69  experience_Россельхозбанк                                                   2842 non-null   int64
#  70  experience_Ozon                                                             2842 non-null   int64
#  71  experience_Билайн                                                           2842 non-null   int64
#  72  experience_Интернет-магазин                                                 2842 non-null   int64
#  73  experience_Тинькофф Банк                                                    2842 non-null   int64
#  74  experience_Пепсико Россия                                                   2842 non-null   int64
#  75  experience_РЖД                                                              2842 non-null   int64
#  76  experience_НИУ ВШЭ                                                          2842 non-null   int64
#  77  experience_Промсвязьбанк                                                    2842 non-null   int64
#  78  experience_EY Russia                                                        2842 non-null   int64
#  79  experience_Газпромбанк                                                      2842 non-null   int64
#  80  experience_Raiffeisenbank                                                   2842 non-null   int64
#  81  experience_X5 Retail Group                                                  2842 non-null   int64
#  82  experience_Совкомбанк                                                       2842 non-null   int64
#  83  experience_ФК Открытие                                                      2842 non-null   int64
#  84  experience_ЦБ РФ                                                            2842 non-null   int64
#  85  experience_МегаФон                                                          2842 non-null   int64
#  86  experience_Банк Уралсиб                                                     2842 non-null   int64
#  87  experience_Яндекс Практикум                                                 2842 non-null   int64
#  88  experience_Почта России                                                     2842 non-null   int64
#  89  experience_Philip Morris International                                      2842 non-null   int64
#  90  experience_VK                                                               2842 non-null   int64
#  91  experience_Иннотех                                                          2842 non-null   int64
#  92  experience_Банк Хоум Кредит                                                 2842 non-null   int64
#  93  experience_Wildberries                                                      2842 non-null   int64
#  94  experience_Аэропорт Домодедово                                              2842 non-null   int64
#  95  experience_Tele2                                                            2842 non-null   int64
#  96  experience_Лента                                                            2842 non-null   int64
# dtypes: float64(5), int32(12), int64(78), object(2)
# memory usage: 2.0+ MB

# %%
def clean_skills(skill_str):
    skill_str = skill_str.strip('{}')
    skills = re.findall(r'(?:[^,"]|"(?:\\.|[^"])*")+', skill_str)
    skills = [s.strip().strip('"') for s in skills if s.strip()]
    return skills

df['employments_cleaned'] = df['employments'].apply(clean_skills)

selected_employments = [
    'Полная занятость',
    'Частичная занятость',
    'Проектная работа',
    'Стажировка'
]


for employments in selected_employments:
    df[f'employments_{employments}'] = df['employments_cleaned'].apply(lambda x: 1 if employments in x else 0)

df = df.drop(columns=['employments', 'employments_cleaned'])

# %%
def clean_skills(skill_str):
    skill_str = skill_str.strip('{}')
    skills = re.findall(r'(?:[^,"]|"(?:\\.|[^"])*")+', skill_str)
    skills = [s.strip().strip('"') for s in skills if s.strip()]
    return skills

df['university_cleaned'] = df['university'].apply(clean_skills)

selected_university = [
    "Финансовый университет при Правительстве Российской Федерации",
    "Национальный исследовательский университет 'Высшая школа экономики'",
    "Московский государственный университет им. М.В. Ломоносова",
    "Российский экономический университет им. Г.В. Плеханова",
    "Российская академия народного хозяйства и государственной службы при Президенте РФ",
    "Санкт-Петербургский государственный университет",
    "Московский авиационный институт (национальный исследовательский университет)",
    "Московский государственный технический университет им. Н.Э. Баумана",
    "Московский физико-технический институт (Государственный университет)",
    "Уральский федеральный университет имени первого Президента России Б.Н. Ельцина",
    "Национальный исследовательский ядерный университет 'МИФИ'",
    "Государственный университет управления",
    "Кубанский государственный университет",
    "Казанский (Приволжский) федеральный университет",
    "Санкт-Петербургский политехнический университет Петра Великого",
    "Воронежский государственный университет",
    "Нижегородский государственный университет им. Н.И. Лобачевского",
    "Российский государственный университет нефти и газа им. И.М. Губкина",
    "Московский энергетический институт (Национальный исследовательский университет)",
    "Российский университет дружбы народов"
]


for university in selected_university:
    df[f'university_{university}'] = df['university_cleaned'].apply(lambda x: 1 if university in x else 0)

df = df.drop(columns=['university', 'university_cleaned'])

# %%
df = df[(df['russian_salary'] >= 30000) & (df['russian_salary'] <= 500000)]

# %%
df1=df.copy()

# %%
df1 = df1.drop(columns=['count_additional_courses'])

# %%
df1.columns
# Out:
# Index(['age', 'total_experience', 'russian_salary', 'language_eng', 'photo',
#        'is_driver', 'gender_female', 'gender_male', 'citizenship_russia',
#        'citizenship_other',
#        ...
#        'university_Национальный исследовательский ядерный университет 'МИФИ'',
#        'university_Государственный университет управления',
#        'university_Кубанский государственный университет',
#        'university_Казанский (Приволжский) федеральный университет',
#        'university_Санкт-Петербургский политехнический университет Петра Великого',
#        'university_Воронежский государственный университет',
#        'university_Нижегородский государственный университет им. Н.И. Лобачевского',
#        'university_Российский государственный университет нефти и газа им. И.М. Губкина',
#        'university_Московский энергетический институт (Национальный исследовательский университет)',
#        'university_Российский университет дружбы народов'],
#       dtype='object', length=118)

# %%
# Референтые группы 
X = df1.drop(columns=['russian_salary', 'gender_male', 'citizenship_russia' ,
                     'area_Москва'])  # Предикторы
y = df1['russian_salary']  # Целевая переменная

X = sm.add_constant(X)

model1 = sm.OLS(y, X).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         russian_salary   R-squared:                       0.407
# Model:                            OLS   Adj. R-squared:                  0.385
# Method:                 Least Squares   F-statistic:                     18.55
# Date:                Tue, 08 Apr 2025   Prob (F-statistic):          1.80e-235
# Time:                        02:39:27   Log-Likelihood:                -35348.
# No. Observations:                2804   AIC:                         7.090e+04
# Df Residuals:                    2703   BIC:                         7.150e+04
# Df Model:                         100
# Covariance Type:            nonrobust
# =================================================================================================================================================================
#                                                                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                
# university_Финансовый университет при Правительстве Российской Федерации                       1730.9825   8917.189      0.194      0.846   -1.58e+04    1.92e+04
# university_Национальный исследовательский университет 'Высшая школа экономики'                 2.498e-11   7.06e-12      3.536      0.000    1.11e-11    3.88e-11
# university_Московский государственный университет им. М.В. Ломоносова                          4404.5504   1.19e+04      0.371      0.711   -1.89e+04    2.77e+04
# university_Российский экономический университет им. Г.В. Плеханова                             1.683e+04   9552.232      1.762      0.078   -1902.904    3.56e+04
# university_Российская академия народного хозяйства и государственной службы при Президенте РФ  1.558e+04   9405.783      1.656      0.098   -2863.688     3.4e+04
# university_Санкт-Петербургский государственный университет                                     2.208e+04    1.2e+04      1.846      0.065   -1372.064    4.55e+04
# university_Московский авиационный институт (национальный исследовательский университет)        1305.7150   1.31e+04      0.100      0.920   -2.43e+04    2.69e+04
# university_Московский государственный технический университет им. Н.Э. Баумана                 5.644e+04    1.5e+04      3.764      0.000     2.7e+04    8.58e+04
# university_Московский физико-технический институт (Государственный университет)                5.291e+04   1.74e+04      3.049      0.002    1.89e+04    8.69e+04
# university_Уральский федеральный университет имени первого Президента России Б.Н. Ельцина      2.433e+04   1.44e+04      1.694      0.090   -3834.987    5.25e+04
# university_Национальный исследовательский ядерный университет 'МИФИ'                                   0          0        nan        nan           0           0
# university_Государственный университет управления                                             -2.853e+04   1.31e+04     -2.184      0.029   -5.41e+04   -2912.993
# university_Кубанский государственный университет                                              -3868.7581   1.67e+04     -0.231      0.817   -3.67e+04     2.9e+04
# university_Казанский (Приволжский) федеральный университет                                    -3749.1436   1.79e+04     -0.209      0.834   -3.88e+04    3.13e+04
# university_Санкт-Петербургский политехнический университет Петра Великого                     -8754.9725   2.07e+04     -0.423      0.673   -4.94e+04    3.19e+04
# university_Воронежский государственный университет                                            -2.053e+04   1.87e+04     -1.101      0.271   -5.71e+04     1.6e+04
# university_Нижегородский государственный университет им. Н.И. Лобачевского                             0          0        nan        nan           0           0
# university_Российский государственный университет нефти и газа им. И.М. Губкина                3273.5587   1.73e+04      0.189      0.850   -3.06e+04    3.72e+04
# university_Московский энергетический институт (Национальный исследовательский университет)    -2.232e+04   2.03e+04     -1.098      0.272   -6.22e+04    1.75e+04
# university_Российский университет дружбы народов                                              -3.065e+04   2.16e+04     -1.421      0.156   -7.29e+04    1.17e+04
# ==============================================================================
# Omnibus:                      342.546   Durbin-Watson:                   1.923
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              571.546
# Skew:                           0.831   Prob(JB):                    7.77e-125
# Kurtosis:                       4.458   Cond. No.                     1.71e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.95e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Флаг для контроля остановки
all_significant = False

while not all_significant:
    model = sm.OLS(y, X).fit()
    p_values = model.pvalues.drop('const', errors='ignore')
    
    if (p_values <= 0.05).all():
        all_significant = True
    else:
        max_p_value = p_values.max()
        if max_p_value > 0.05:
            feature_to_drop = p_values.idxmax()
            print(f"Удаляем признак {feature_to_drop} (p-value = {max_p_value:.4f})")
            X = X.drop(columns=[feature_to_drop])
        else:
            all_significant = True

print(model.summary())
# Out:
# Удаляем признак skill_Экономический анализ (p-value = 0.9900)
# Удаляем признак experience_Почта России (p-value = 0.9444)
# Удаляем признак university_Московский авиационный институт (национальный исследовательский университет) (p-value = 0.9173)
# Удаляем признак skill_Power BI (p-value = 0.8725)
# Удаляем признак experience_ЦБ РФ (p-value = 0.9840)
# Удаляем признак experience_Магнит (p-value = 0.9291)
# Удаляем признак experience_Росбанк (p-value = 0.8655)
# Удаляем признак university_Российский государственный университет нефти и газа им. И.М. Губкина (p-value = 0.8540)
# Удаляем признак experience_Philip Morris International (p-value = 0.9543)
# Удаляем признак university_Финансовый университет при Правительстве Российской Федерации (p-value = 0.8464)
# Удаляем признак university_Национальный исследовательский университет 'Высшая школа экономики' (p-value = 0.8981)
# Удаляем признак skill_Разработка технических заданий (p-value = 0.8410)
# Удаляем признак experience_X5 Retail Group (p-value = 0.9335)
# Удаляем признак skill_Анализ финансовых показателей (p-value = 0.8268)
# Удаляем признак skill_Анализ бизнес показателей (p-value = 0.8427)
# Удаляем признак university_Кубанский государственный университет (p-value = 0.8149)
# Удаляем признак experience_Банк Уралсиб (p-value = 0.9752)
# Удаляем признак university_Казанский (Приволжский) федеральный университет (p-value = 0.8139)
# Удаляем признак schedules_Вахтовый метод (p-value = 0.8060)
# Удаляем признак experience_Лента (p-value = 0.8027)
# Удаляем признак university_Московский государственный университет им. М.В. Ломоносова (p-value = 0.7227)
# Удаляем признак experience_Яндекс Практикум (p-value = 0.6877)
# Удаляем признак experience_Банк ВТБ (p-value = 0.9367)
# Удаляем признак experience_РЖД (p-value = 0.7286)
# Удаляем признак experience_ФК Открытие (p-value = 0.8066)
# Удаляем признак university_Национальный исследовательский ядерный университет 'МИФИ' (p-value = 0.8077)
# Удаляем признак university_Санкт-Петербургский политехнический университет Петра Великого (p-value = 0.6569)
# Удаляем признак employments_Полная занятость (p-value = 0.6301)
# Удаляем признак citizenship_other (p-value = 0.6233)
# Удаляем признак skill_MS Excel (p-value = 0.5820)
# Удаляем признак skill_Power Query (p-value = 0.6185)
# Удаляем признак experience_МТС (p-value = 0.5542)
# Удаляем признак experience_Т-Банк (p-value = 0.5827)
# Удаляем признак experience_Аэропорт Домодедово (p-value = 0.6015)
# Удаляем признак experience_НИУ ВШЭ (p-value = 0.9825)
# Удаляем признак university_Нижегородский государственный университет им. Н.И. Лобачевского (p-value = 0.6837)
# Удаляем признак experience_Интернет-магазин (p-value = 0.5414)
# Удаляем признак experience_Tele2 (p-value = 0.5684)
# Удаляем признак skill_PostgreSQL (p-value = 0.5395)
# Удаляем признак skill_Бизнес-анализ (p-value = 0.5083)
# Удаляем признак experience_Группа компаний (p-value = 0.4690)
# Удаляем признак skill_1С: Предприятие 8 (p-value = 0.4352)
# Удаляем признак skill_UML (p-value = 0.3989)
# Удаляем признак schedules_Полный день (p-value = 0.3905)
# Удаляем признак photo (p-value = 0.3557)
# Удаляем признак experience_Ростелеком (p-value = 0.3378)
# Удаляем признак university_Московский энергетический институт (Национальный исследовательский университет) (p-value = 0.3357)
# Удаляем признак experience_Совкомбанк (p-value = 0.3407)
# Удаляем признак experience_Ozon (p-value = 0.3239)
# Удаляем признак university_Воронежский государственный университет (p-value = 0.2763)
# Удаляем признак experience_Альфа-Банк (p-value = 0.2518)
# Удаляем признак skill_Статистический анализ (p-value = 0.2590)
# Удаляем признак experience_Россельхозбанк (p-value = 0.2450)
# Удаляем признак schedules_Гибкий график (p-value = 0.1963)
# Удаляем признак skill_Python (p-value = 0.1781)
# Удаляем признак skill_Atlassian Jira (p-value = 0.1719)
# Удаляем признак university_Российский университет дружбы народов (p-value = 0.1376)
# Удаляем признак university_Российская академия народного хозяйства и государственной службы при Президенте РФ (p-value = 0.1337)
# Удаляем признак skill_MS PowerPoint (p-value = 0.1231)
# Удаляем признак experience_EY Russia (p-value = 0.1251)
# Удаляем признак university_Российский экономический университет им. Г.В. Плеханова (p-value = 0.1114)
# Удаляем признак university_Уральский федеральный университет имени первого Президента России Б.Н. Ельцина (p-value = 0.1127)
# Удаляем признак skill_Моделирование бизнес процессов (p-value = 0.0915)
# Удаляем признак skill_MS Visio (p-value = 0.0857)
# Удаляем признак experience_Промсвязьбанк (p-value = 0.0864)
# Удаляем признак university_Санкт-Петербургский государственный университет (p-value = 0.0680)
# Удаляем признак experience_МегаФон (p-value = 0.0687)
# Удаляем признак skill_Управленческая отчетность (p-value = 0.0651)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         russian_salary   R-squared:                       0.395
# Model:                            OLS   Adj. R-squared:                  0.385
# Method:                 Least Squares   F-statistic:                     39.14
# Date:                Tue, 08 Apr 2025   Prob (F-statistic):          2.22e-262
# Time:                        02:39:29   Log-Likelihood:                -35375.
# No. Observations:                2804   AIC:                         7.084e+04
# Df Residuals:                    2757   BIC:                         7.112e+04
# Df Model:                          46
# Covariance Type:            nonrobust
# ===================================================================================================================================================
#                                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                            1.188e+05   1.24e+04      9.550      0.000    9.44e+04    1.43e+05
# age                                                                             -1414.7795    320.809     -4.410      0.000   -2043.830    -785.729
# total_experience                                                                  224.4495     30.943      7.254      0.000     163.775     285.124
# language_eng                                                                     4460.1175   1007.130      4.429      0.000    2485.312    6434.923
# is_driver                                                                        9977.0981   2924.420      3.412      0.001    4242.823    1.57e+04
# gender_female                                                                   -2.302e+04   3006.780     -7.655      0.000   -2.89e+04   -1.71e+04
# area_other                                                                      -5.069e+04   3299.010    -15.365      0.000   -5.72e+04   -4.42e+04
# area_Казань                                                                     -4.515e+04   1.04e+04     -4.335      0.000   -6.56e+04   -2.47e+04
# area_Краснодар                                                                  -5.418e+04   8053.334     -6.727      0.000      -7e+04   -3.84e+04
# area_Нижний Новгород                                                            -5.883e+04   1.06e+04     -5.557      0.000   -7.96e+04   -3.81e+04
# area_Санкт-Петербург                                                            -3.899e+04   4689.690     -8.315      0.000   -4.82e+04   -2.98e+04
# skill_Работа с большим объемом информации                                       -9617.1084   3429.472     -2.804      0.005   -1.63e+04   -2892.515
# skill_Аналитическое мышление                                                    -1.062e+04   3447.306     -3.080      0.002   -1.74e+04   -3859.199
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              555.138
# Skew:                           0.838   Prob(JB):                    2.84e-121
# Kurtosis:                       4.395   Cond. No.                     5.55e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.55e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
def calculate_vifs(X):
    vif_data = pd.DataFrame()
    # Исключаем 'const' из расчета VIF
    features = [col for col in X.columns if col != 'const']
    vif_data["feature"] = features
    vif_data["VIF"] = [variance_inflation_factor(X[features].values, i) for i in range(len(features))]
    return vif_data
    
high_vif = True
while high_vif:
    vifs = calculate_vifs(X)
    max_vif = vifs['VIF'].max()
    
    if max_vif > 5:  # Порог VIF
        feature_to_drop = vifs.loc[vifs['VIF'].idxmax(), 'feature']
        print(f"Удаляем признак {feature_to_drop} (VIF = {max_vif:.2f})")
        X = X.drop(columns=[feature_to_drop])
    else:
        high_vif = False

# Финальная модель
final_model = sm.OLS(y, X).fit()
print(final_model.summary())

# Вывод итоговых VIF
print("\nФинальные VIF значения:")
print(calculate_vifs(X).sort_values('VIF', ascending=False))
# Out:
# Удаляем признак age (VIF = 46.90)
# Удаляем признак level_education (VIF = 13.28)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         russian_salary   R-squared:                       0.382
# Model:                            OLS   Adj. R-squared:                  0.372
# Method:                 Least Squares   F-statistic:                     38.73
# Date:                Tue, 08 Apr 2025   Prob (F-statistic):          2.38e-251
# Time:                        02:39:31   Log-Likelihood:                -35406.
# No. Observations:                2804   AIC:                         7.090e+04
# Df Residuals:                    2759   BIC:                         7.117e+04
# Df Model:                          44
# Covariance Type:            nonrobust
# ===================================================================================================================================================
#                                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                            1.408e+05   5837.202     24.117      0.000    1.29e+05    1.52e+05
# total_experience                                                                  112.6069     16.570      6.796      0.000      80.117     145.097
# language_eng                                                                     5426.2646   1009.219      5.377      0.000    3447.363    7405.166
# is_driver                                                                        1.252e+04   2936.498      4.264      0.000    6763.348    1.83e+04
# gender_female                                                                   -2.126e+04   3029.707     -7.018      0.000   -2.72e+04   -1.53e+04
# area_other                                                                      -5.299e+04   3319.635    -15.963      0.000   -5.95e+04   -4.65e+04
# area_Казань                                                                     -4.703e+04   1.05e+04     -4.469      0.000   -6.77e+04   -2.64e+04
# area_Краснодар                                                                  -5.767e+04   8120.854     -7.102      0.000   -7.36e+04   -4.17e+04
# area_Нижний Новгород                                                             -5.85e+04   1.07e+04     -5.474      0.000   -7.95e+04   -3.75e+04
# area_Санкт-Петербург                                                            -4.226e+04   4719.614     -8.954      0.000   -5.15e+04    -3.3e+04
# skill_Работа с большим объемом информации                                       -9412.7880   3458.537     -2.722      0.007   -1.62e+04   -2631.205
# skill_Аналитическое мышление                                                    -1.039e+04   3482.036     -2.985      0.003   -1.72e+04   -3566.935
# skill_SQL                                                                         1.38e+04   3795.551      3.637      0.000    6361.705    2.12e+04
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              591.235
# Skew:                           0.843   Prob(JB):                    4.12e-129
# Kurtosis:                       4.488   Cond. No.                     5.45e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Финальные VIF значения:
#                                               feature       VIF
# 23                         schedules_Удаленная работа  3.649594
# 1                                        language_eng  3.600030
# 0                                    total_experience  3.084541
# 38                    employments_Частичная занятость  3.057709
# 39                       employments_Проектная работа  2.302943
# 2                                           is_driver  2.261928
# 4                                          area_other  1.902334
# 11                                          skill_SQL  1.871409
# 3                                       gender_female  1.763693
# 24                           schedules_Сменный график  1.719745
# 12                                         skill_BPMN  1.692911
# 9           skill_Работа с большим объемом информации  1.625888
# 10                       skill_Аналитическое мышление  1.619624
# 13               skill_Постановка задач разработчикам  1.465215
# 6                                      area_Краснодар  1.429824
# 14                             skill_Системный анализ  1.401222
# 27                          experience_Розничная сеть  1.396104
# 15                         skill_Atlassian Confluence  1.386508
# 40                             employments_Стажировка  1.348116
# 21                 skill_Оптимизация бизнес-процессов  1.297269
# 8                                area_Санкт-Петербург  1.289674
# 20                                          skill_Git  1.248210
# 18                      skill_Автоматизация процессов  1.210198
# 19                          skill_Визуализация данных  1.198099
# 22                              skill_Прогнозирование  1.168087
# 17                                       skill_MS SQL  1.140310
# 16                            skill_Финансовый анализ  1.135390
# 25                                    experience_Сбер  1.117789
# 28                                  experience_Яндекс  1.102412
# 33                          experience_Raiffeisenbank  1.084904
# 26  experience_Индивидуальное предпринимательство ...  1.082799
# 7                                area_Нижний Новгород  1.077012
# 41  university_Московский государственный техничес...  1.070907
# 37                             experience_Wildberries  1.066268
# 5                                         area_Казань  1.059051
# 32                             experience_Газпромбанк  1.055998
# 34                                      experience_VK  1.052250
# 35                                 experience_Иннотех  1.047411
# 43  university_Государственный университет управления  1.046416
# 36                        experience_Банк Хоум Кредит  1.033972
# 42  university_Московский физико-технический инсти...  1.031969
# 29                                  experience_Билайн  1.030494
# 30                           experience_Тинькофф Банк  1.027871
# 31                          experience_Пепсико Россия  1.022808

# %%
X.corrwith(y).sort_values()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\User\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# area_other                                                                        -0.247417
# gender_female                                                                     -0.200720
# employments_Стажировка                                                            -0.169978
# employments_Частичная занятость                                                   -0.159037
# schedules_Сменный график                                                          -0.155103
# skill_Работа с большим объемом информации                                         -0.106128
# area_Санкт-Петербург                                                              -0.083962
# area_Краснодар                                                                    -0.054880
# area_Казань                                                                       -0.032601
# area_Нижний Новгород                                                              -0.031036
# experience_Индивидуальное предпринимательство / частная практика / фриланс        -0.022168
# skill_Визуализация данных                                                         -0.020349
# employments_Проектная работа                                                      -0.020000
# university_Государственный университет управления                                 -0.011901
# skill_Аналитическое мышление                                                      -0.011703
# experience_Розничная сеть                                                         -0.010914
# experience_Пепсико Россия                                                          0.023611
# skill_Прогнозирование                                                              0.032522
# skill_Финансовый анализ                                                            0.035754
# experience_Банк Хоум Кредит                                                        0.037066
# total_experience                                                                   0.037617
# schedules_Удаленная работа                                                         0.050562
# experience_Билайн                                                                  0.054713
# experience_Тинькофф Банк                                                           0.059466
# experience_Газпромбанк                                                             0.066724
# experience_Wildberries                                                             0.067176
# is_driver                                                                          0.067356
# experience_Яндекс                                                                  0.078593
# skill_Автоматизация процессов                                                      0.081849
# university_Московский физико-технический институт (Государственный университет)    0.081902
# university_Московский государственный технический университет им. Н.Э. Баумана     0.102297
# experience_Иннотех                                                                 0.104850
# experience_Raiffeisenbank                                                          0.114186
# skill_Оптимизация бизнес-процессов                                                 0.118541
# experience_Сбер                                                                    0.122962
# skill_Git                                                                          0.135568
# skill_Системный анализ                                                             0.166795
# skill_MS SQL                                                                       0.177491
# experience_VK                                                                      0.188806
# skill_BPMN                                                                         0.192585
# language_eng                                                                       0.193672
# skill_Постановка задач разработчикам                                               0.209388
# skill_SQL                                                                          0.215595
# skill_Atlassian Confluence                                                         0.234668
# const                                                                                   NaN
# dtype: float64

# %%
df.columns
# Out:
# Index(['age', 'total_experience', 'count_additional_courses', 'russian_salary',
#        'language_eng', 'photo', 'is_driver', 'gender_female', 'gender_male',
#        'citizenship_russia',
#        ...
#        'university_Национальный исследовательский ядерный университет 'МИФИ'',
#        'university_Государственный университет управления',
#        'university_Кубанский государственный университет',
#        'university_Казанский (Приволжский) федеральный университет',
#        'university_Санкт-Петербургский политехнический университет Петра Великого',
#        'university_Воронежский государственный университет',
#        'university_Нижегородский государственный университет им. Н.И. Лобачевского',
#        'university_Российский государственный университет нефти и газа им. И.М. Губкина',
#        'university_Московский энергетический институт (Национальный исследовательский университет)',
#        'university_Российский университет дружбы народов'],
#       dtype='object', length=119)

# %%
df2=df.copy()
df2['count_additional_courses'].fillna(df2['count_additional_courses'].median(), inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18632\1888289706.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['count_additional_courses'].fillna(df2['count_additional_courses'].median(), inplace=True)

# %%
df2['count_additional_courses'].value_counts()
# Out:
# count_additional_courses
# 2.0     1726
# 1.0      482
# 3.0      181
# 4.0      113
# 6.0       69
# 5.0       65
# 7.0       38
# 8.0       26
# 10.0      22
# 11.0      17
# 9.0       14
# 12.0      11
# 14.0      11
# 19.0       6
# 15.0       5
# 21.0       4
# 13.0       4
# 17.0       4
# 52.0       2
# 18.0       2
# 16.0       1
# 22.0       1
# Name: count, dtype: int64

# %%
# Референтые группы 
X = df2.drop(columns=['russian_salary', 'gender_male', 'citizenship_russia' ,
                     'area_Москва'])  # Предикторы
y = df2['russian_salary']  # Целевая переменная

X = sm.add_constant(X)

model1 = sm.OLS(y, X).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         russian_salary   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.386
# Method:                 Least Squares   F-statistic:                     18.43
# Date:                Tue, 08 Apr 2025   Prob (F-statistic):          1.00e-235
# Time:                        02:39:32   Log-Likelihood:                -35345.
# No. Observations:                2804   AIC:                         7.089e+04
# Df Residuals:                    2702   BIC:                         7.150e+04
# Df Model:                         101
# Covariance Type:            nonrobust
# =================================================================================================================================================================
#                                                                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                
-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Флаг для контроля остановки
all_significant = False

while not all_significant:
    model = sm.OLS(y, X).fit()
    p_values = model.pvalues.drop('const', errors='ignore')
    
    if (p_values <= 0.05).all():
        all_significant = True
    else:
        max_p_value = p_values.max()
        if max_p_value > 0.05:
            feature_to_drop = p_values.idxmax()
            print(f"Удаляем признак {feature_to_drop} (p-value = {max_p_value:.4f})")
            X = X.drop(columns=[feature_to_drop])
        else:
            all_significant = True

print(model.summary())
# Out:
# Удаляем признак university_Московский авиационный институт (национальный исследовательский университет) (p-value = 0.9493)
# Удаляем признак experience_НИУ ВШЭ (p-value = 0.9495)
# Удаляем признак skill_Экономический анализ (p-value = 0.9402)
# Удаляем признак experience_Магнит (p-value = 0.9676)
# Удаляем признак skill_Power BI (p-value = 0.9341)
# Удаляем признак experience_Tele2 (p-value = 0.9570)
# Удаляем признак experience_X5 Retail Group (p-value = 0.9542)
# Удаляем признак experience_Почта России (p-value = 0.9102)
# Удаляем признак experience_Росбанк (p-value = 0.8943)
# Удаляем признак university_Финансовый университет при Правительстве Российской Федерации (p-value = 0.8881)
# Удаляем признак skill_Анализ финансовых показателей (p-value = 0.8548)
# Удаляем признак skill_Разработка технических заданий (p-value = 0.8476)
# Удаляем признак experience_ФК Открытие (p-value = 0.8558)
# Удаляем признак experience_Банк Уралсиб (p-value = 0.8606)
# Удаляем признак university_Российский государственный университет нефти и газа им. И.М. Губкина (p-value = 0.8437)
# Удаляем признак experience_Лента (p-value = 0.8353)
# Удаляем признак experience_Philip Morris International (p-value = 0.8968)
# Удаляем признак experience_ЦБ РФ (p-value = 0.8754)
# Удаляем признак university_Кубанский государственный университет (p-value = 0.8301)
# Удаляем признак university_Казанский (Приволжский) федеральный университет (p-value = 0.8270)
# Удаляем признак skill_Анализ бизнес показателей (p-value = 0.7903)
# Удаляем признак schedules_Вахтовый метод (p-value = 0.7569)
# Удаляем признак university_Санкт-Петербургский политехнический университет Петра Великого (p-value = 0.6836)
# Удаляем признак university_Московский государственный университет им. М.В. Ломоносова (p-value = 0.6816)
# Удаляем признак skill_MS Excel (p-value = 0.6640)
# Удаляем признак skill_Power Query (p-value = 0.6880)
# Удаляем признак experience_Аэропорт Домодедово (p-value = 0.6494)
# Удаляем признак experience_Банк ВТБ (p-value = 0.8043)
# Удаляем признак citizenship_other (p-value = 0.6479)
# Удаляем признак university_Национальный исследовательский университет 'Высшая школа экономики' (p-value = 0.7908)
# Удаляем признак experience_Яндекс Практикум (p-value = 0.6488)
# Удаляем признак experience_РЖД (p-value = 0.9789)
# Удаляем признак employments_Полная занятость (p-value = 0.6162)
# Удаляем признак skill_Бизнес-анализ (p-value = 0.5933)
# Удаляем признак experience_Интернет-магазин (p-value = 0.5528)
# Удаляем признак experience_МТС (p-value = 0.5500)
# Удаляем признак experience_Т-Банк (p-value = 0.5690)
# Удаляем признак experience_Группа компаний (p-value = 0.5223)
# Удаляем признак university_Нижегородский государственный университет им. Н.И. Лобачевского (p-value = 0.9103)
# Удаляем признак university_Национальный исследовательский ядерный университет 'МИФИ' (p-value = 0.5934)
# Удаляем признак skill_PostgreSQL (p-value = 0.5178)
# Удаляем признак skill_1С: Предприятие 8 (p-value = 0.4780)
# Удаляем признак photo (p-value = 0.4894)
# Удаляем признак schedules_Гибкий график (p-value = 0.3570)
# Удаляем признак skill_UML (p-value = 0.3468)
# Удаляем признак experience_Ozon (p-value = 0.3186)
# Удаляем признак experience_Ростелеком (p-value = 0.2920)
# Удаляем признак university_Московский энергетический институт (Национальный исследовательский университет) (p-value = 0.2872)
# Удаляем признак experience_Совкомбанк (p-value = 0.2891)
# Удаляем признак university_Воронежский государственный университет (p-value = 0.2740)
# Удаляем признак skill_Статистический анализ (p-value = 0.2454)
# Удаляем признак experience_Альфа-Банк (p-value = 0.2606)
# Удаляем признак schedules_Полный день (p-value = 0.2577)
# Удаляем признак skill_Python (p-value = 0.2612)
# Удаляем признак experience_Россельхозбанк (p-value = 0.2142)
# Удаляем признак skill_Atlassian Jira (p-value = 0.1472)
# Удаляем признак university_Уральский федеральный университет имени первого Президента России Б.Н. Ельцина (p-value = 0.1371)
# Удаляем признак university_Российский университет дружбы народов (p-value = 0.1326)
# Удаляем признак university_Российская академия народного хозяйства и государственной службы при Президенте РФ (p-value = 0.1513)
# Удаляем признак experience_Промсвязьбанк (p-value = 0.1245)
# Удаляем признак experience_EY Russia (p-value = 0.1177)
# Удаляем признак university_Российский экономический университет им. Г.В. Плеханова (p-value = 0.1070)
# Удаляем признак skill_Моделирование бизнес процессов (p-value = 0.0884)
# Удаляем признак experience_МегаФон (p-value = 0.0873)
# Удаляем признак skill_MS PowerPoint (p-value = 0.0770)
# Удаляем признак skill_Оптимизация бизнес-процессов (p-value = 0.0851)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         russian_salary   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     37.11
# Date:                Tue, 08 Apr 2025   Prob (F-statistic):          1.56e-262
# Time:                        02:39:34   Log-Likelihood:                -35369.
# No. Observations:                2804   AIC:                         7.084e+04
# Df Residuals:                    2754   BIC:                         7.114e+04
# Df Model:                          49
# Covariance Type:            nonrobust
# ===================================================================================================================================================
#                                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                              1.2e+05   1.25e+04      9.622      0.000    9.55e+04    1.44e+05
# age                                                                             -1382.8496    320.382     -4.316      0.000   -2011.063    -754.637
# total_experience                                                                  210.9016     31.128      6.775      0.000     149.865     271.938
# count_additional_courses                                                         1268.8185    527.682      2.405      0.016     234.125    2303.512
# language_eng                                                                     4199.5435   1011.988      4.150      0.000    2215.210    6183.877
# is_driver                                                                        1.009e+04   2930.251      3.444      0.001    4346.505    1.58e+04
# gender_female                                                                   -2.252e+04   3010.155     -7.481      0.000   -2.84e+04   -1.66e+04
# area_other                                                                      -5.063e+04   3296.846    -15.356      0.000   -5.71e+04   -4.42e+04
# area_Казань                                                                     -4.814e+04   1.05e+04     -4.606      0.000   -6.86e+04   -2.76e+04
# area_Краснодар                                                                  -5.637e+04   8051.817     -7.001      0.000   -7.22e+04   -4.06e+04
# area_Нижний Новгород                                                            -5.988e+04   1.06e+04     -5.663      0.000   -8.06e+04   -3.91e+04
# experience_Wildberries                                                             1.4e+05   4.38e+04      3.197      0.001    5.41e+04    2.26e+05
# employments_Частичная занятость                                                 -2.297e+04   3984.998     -5.764      0.000   -3.08e+04   -1.52e+04
# employments_Проектная работа                                                     1.206e+04   4124.212      2.925      0.003    3975.623    2.01e+04
# employments_Стажировка                                                          -3.472e+04   5273.041     -6.585      0.000   -4.51e+04   -2.44e+04
# university_Санкт-Петербургский государственный университет                       2.264e+04   1.15e+04      1.973      0.049     142.370    4.51e+04
# university_Московский государственный технический университет им. Н.Э. Баумана   5.026e+04   1.41e+04      3.556      0.000    2.25e+04     7.8e+04
# university_Московский физико-технический институт (Государственный университет)   5.18e+04   1.71e+04      3.023      0.003    1.82e+04    8.54e+04
# university_Государственный университет управления                               -2.548e+04   1.29e+04     -1.977      0.048   -5.08e+04    -204.436
# ==============================================================================
# Omnibus:                      344.463   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              571.630
# Skew:                           0.838   Prob(JB):                    7.45e-125
# Kurtosis:                       4.444   Cond. No.                     5.55e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.55e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
def calculate_vifs(X):
    vif_data = pd.DataFrame()
    # Исключаем 'const' из расчета VIF
    features = [col for col in X.columns if col != 'const']
    vif_data["feature"] = features
    vif_data["VIF"] = [variance_inflation_factor(X[features].values, i) for i in range(len(features))]
    return vif_data
    
high_vif = True
while high_vif:
    vifs = calculate_vifs(X)
    max_vif = vifs['VIF'].max()
    
    if max_vif > 10:  # Порог VIF
        feature_to_drop = vifs.loc[vifs['VIF'].idxmax(), 'feature']
        print(f"Удаляем признак {feature_to_drop} (VIF = {max_vif:.2f})")
        X = X.drop(columns=[feature_to_drop])
    else:
        high_vif = False

# Финальная модель
final_model = sm.OLS(y, X).fit()
print(final_model.summary())

# Вывод итоговых VIF
print("\nФинальные VIF значения:")
print(calculate_vifs(X).sort_values('VIF', ascending=False))
# Out:
# Удаляем признак age (VIF = 47.08)
# Удаляем признак level_education (VIF = 13.48)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         russian_salary   R-squared:                       0.386
# Model:                            OLS   Adj. R-squared:                  0.375
# Method:                 Least Squares   F-statistic:                     36.83
# Date:                Tue, 08 Apr 2025   Prob (F-statistic):          9.55e-253
# Time:                        02:39:37   Log-Likelihood:                -35397.
# No. Observations:                2804   AIC:                         7.089e+04
# Df Residuals:                    2756   BIC:                         7.117e+04
# Df Model:                          47
# Covariance Type:            nonrobust
# ===================================================================================================================================================
#                                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                            1.393e+05   5862.912     23.754      0.000    1.28e+05    1.51e+05
# total_experience                                                                   99.7211     16.880      5.908      0.000      66.622     132.820
# count_additional_courses                                                         1373.7787    532.449      2.580      0.010     329.739    2417.818
# language_eng                                                                     5038.0889   1014.472      4.966      0.000    3048.887    7027.291
# is_driver                                                                        1.256e+04   2938.398      4.274      0.000    6795.925    1.83e+04
# gender_female                                                                   -2.064e+04   3027.429     -6.819      0.000   -2.66e+04   -1.47e+04
# area_other                                                                      -5.273e+04   3314.971    -15.906      0.000   -5.92e+04   -4.62e+04
# area_Казань                                                                     -5.047e+04   1.05e+04     -4.786      0.000   -7.11e+04   -2.98e+04
# area_Краснодар                                                                  -5.961e+04   8110.783     -7.350      0.000   -7.55e+04   -4.37e+04
# experience_Wildberries                                                           1.397e+05   4.42e+04      3.161      0.002     5.3e+04    2.26e+05
# employments_Частичная занятость                                                 -2.331e+04   4019.543     -5.798      0.000   -3.12e+04   -1.54e+04
# employments_Проектная работа                                                     1.058e+04   4147.632      2.551      0.011    2447.327    1.87e+04
# employments_Стажировка                                                          -3.427e+04   5320.466     -6.440      0.000   -4.47e+04   -2.38e+04
# university_Санкт-Петербургский государственный университет                       2.884e+04   1.15e+04      2.501      0.012    6228.560    5.15e+04
# university_Московский государственный технический университет им. Н.Э. Баумана   5.129e+04   1.43e+04      3.596      0.000    2.33e+04    7.93e+04
# university_Московский физико-технический институт (Государственный университет)  5.639e+04   1.73e+04      3.263      0.001    2.25e+04    9.03e+04
# university_Государственный университет управления                               -2.736e+04    1.3e+04     -2.103      0.036   -5.29e+04   -1851.737
# ==============================================================================
# Omnibus:                      355.052   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              608.408
# Skew:                           0.845   Prob(JB):                    7.69e-133
# Kurtosis:                       4.533   Cond. No.                     5.45e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Финальные VIF значения:
#                                               feature       VIF
# 2                                        language_eng  3.739544
# 25                         schedules_Удаленная работа  3.676020
# 0                                    total_experience  3.351531
# 40                    employments_Частичная занятость  3.078554
# 41                       employments_Проектная работа  2.310825
# 3                                           is_driver  2.290481
# 1                            count_additional_courses  2.108012
# 5                                          area_other  1.909786
# 12                                          skill_SQL  1.858945
# 4                                       gender_female  1.771363
# 26                           schedules_Сменный график  1.721716
# 10          skill_Работа с большим объемом информации  1.634089
# 13                                         skill_BPMN  1.631782
# 11                       skill_Аналитическое мышление  1.623674
# 14               skill_Постановка задач разработчикам  1.450331
# 7                                      area_Краснодар  1.436757
# 15                             skill_Системный анализ  1.402710
# 29                          experience_Розничная сеть  1.397597
# 16                         skill_Atlassian Confluence  1.386272
# 9                                area_Санкт-Петербург  1.356291
# 42                             employments_Стажировка  1.353732
# 23                                          skill_Git  1.257115
# 17                            skill_Финансовый анализ  1.248408
# 20                    skill_Управленческая отчетность  1.209122
# 22                          skill_Визуализация данных  1.198959
# 21                      skill_Автоматизация процессов  1.180518
# 24                              skill_Прогнозирование  1.178698
# 18                                       skill_MS SQL  1.171177
# 19                                     skill_MS Visio  1.162212
# 43  university_Санкт-Петербургский государственный...  1.136726
# 27                                    experience_Сбер  1.118776
# 30                                  experience_Яндекс  1.105280
# 35                          experience_Raiffeisenbank  1.085585
# 28  experience_Индивидуальное предпринимательство ...  1.081429
# 8                                area_Нижний Новгород  1.078111
# 6                                         area_Казань  1.071588
# 44  university_Московский государственный техничес...  1.069937
# 39                             experience_Wildberries  1.066584
# 36                                      experience_VK  1.052592
# 34                             experience_Газпромбанк  1.049788
# 37                                 experience_Иннотех  1.048832
# 46  university_Государственный университет управления  1.047435
# 38                        experience_Банк Хоум Кредит  1.034176
# 45  university_Московский физико-технический инсти...  1.033100
# 31                                  experience_Билайн  1.030892
# 32                           experience_Тинькофф Банк  1.029458
# 33                          experience_Пепсико Россия  1.023687
